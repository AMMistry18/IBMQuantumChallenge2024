# %% [markdown]
# ![Notebook_Header_01.png](data:image/png;base64,...)

# %% [markdown]
# # Lab 1: Introduction to Qiskit 1.0

# %% [markdown]
# # Table of Contents
# - [Introduction](#intro)
# - [Part I: Qiskit states, the new and the old](#pt1)
#   - [Exercise 1: Create and draw a singlet Bell state circuit](#exercise1)
#   - [Exercise 2: Use Sampler.run](#exercise2)
#   - [Exercise 3: Create and draw a W-state circuit](#exercise3)
# - [Part II: VQE with Qiskit 1.0](#pt2)
#   - [Exercise 4: Create a parameterized circuit to serve as the ansatz](#exercise4)
#   - [Exercise 5: Transpile to ISA circuits](#exercise5)
#   - [Exercise 6: Defining the cost function](#exercise6)
#   - [Exercise 7: QiskitRuntimeService V2 Primitives, local testing mode and Sessions, a first look](#exercise7)

# %% [markdown]
# ## Setup

# %%
### Install Qiskit, if needed

# %pip install qiskit[visualization]==1.0.2
# %pip install qiskit_aer
# %pip install qiskit_ibm_runtime
# %pip install matplotlib
# %pip install pylatexenc
# %pip install qiskit-transpiler-service
# %pip install git+https://github.com/qiskit-community/Quantum-Challenge-Grader.git
# Out:
# Collecting qiskit==1.0.2 (from qiskit[visualization]==1.0.2)
#   Using cached qiskit-1.0.2-cp38-abi3-win_amd64.whl.metadata (12 kB)
# Collecting rustworkx>=0.14.0 (from qiskit==1.0.2->qiskit[visualization]==1.0.2)
#   Using cached rustworkx-0.14.2-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Collecting numpy<2,>=1.17 (from qiskit==1.0.2->qiskit[visualization]==1.0.2)
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting scipy>=1.5 (from qiskit==1.0.2->qiskit[visualization]==1.0.2)
#   Using cached scipy-1.13.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: sympy>=1.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (1.12.1)
# Collecting dill>=0.3 (from qiskit==1.0.2->qiskit[visualization]==1.0.2)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (2.9.0)
# Collecting stevedore>=3.0.0 (from qiskit==1.0.2->qiskit[visualization]==1.0.2)
#   Using cached stevedore-5.2.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2) (4.12.2)
# Collecting symengine>=0.11 (from qiskit==1.0.2->qiskit[visualization]==1.0.2)
#   Using cached symengine-0.11.0-cp310-cp310-win_amd64.whl.metadata (1.2 kB)
# Collecting matplotlib>=3.3 (from qiskit[visualization]==1.0.2)
#   Using cached matplotlib-3.9.0-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting pydot (from qiskit[visualization]==1.0.2)
#   Using cached pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting Pillow>=4.2.1 (from qiskit[visualization]==1.0.2)
#   Using cached pillow-10.3.0-cp310-cp310-win_amd64.whl.metadata (9.4 kB)
# Requirement already satisfied: pylatexenc>=1.4 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit[visualization]==1.0.2) (2.10)
# Collecting seaborn>=0.9.0 (from qiskit[visualization]==1.0.2)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3->qiskit[visualization]==1.0.2)
#   Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3->qiskit[visualization]==1.0.2)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3->qiskit[visualization]==1.0.2)
#   Using cached fonttools-4.53.0-cp310-cp310-win_amd64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3->qiskit[visualization]==1.0.2)
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2) (24.0)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3->qiskit[visualization]==1.0.2)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: six>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from python-dateutil>=2.8.0->qiskit==1.0.2->qiskit[visualization]==1.0.2) (1.16.0)
# Collecting pandas>=1.2 (from seaborn>=0.9.0->qiskit[visualization]==1.0.2)
#   Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting pbr!=2.1.0,>=2.0.0 (from stevedore>=3.0.0->qiskit==1.0.2->qiskit[visualization]==1.0.2)
#   Using cached pbr-6.0.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from sympy>=1.3->qiskit==1.0.2->qiskit[visualization]==1.0.2) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]==1.0.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]==1.0.2) (2024.1)
# Using cached qiskit-1.0.2-cp38-abi3-win_amd64.whl (4.1 MB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached matplotlib-3.9.0-cp310-cp310-win_amd64.whl (8.0 MB)
# Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Using cached pillow-10.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
# Using cached rustworkx-0.14.2-cp310-cp310-win_amd64.whl (1.6 MB)
# Using cached scipy-1.13.1-cp310-cp310-win_amd64.whl (46.2 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached stevedore-5.2.0-py3-none-any.whl (49 kB)
# Using cached symengine-0.11.0-cp310-cp310-win_amd64.whl (16.7 MB)
# Using cached pydot-2.0.0-py3-none-any.whl (22 kB)
# Using cached contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.0-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached pbr-6.0.0-py2.py3-none-any.whl (107 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: symengine, pyparsing, Pillow, pbr, numpy, kiwisolver, fonttools, dill, cycler, stevedore, scipy, rustworkx, pydot, pandas, contourpy, qiskit, matplotlib, seaborn
# Successfully installed Pillow-10.3.0 contourpy-1.2.1 cycler-0.12.1 dill-0.3.8 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 numpy-1.26.4 pandas-2.2.2 pbr-6.0.0 pydot-2.0.0 pyparsing-3.1.2 qiskit-1.0.2 rustworkx-0.14.2 scipy-1.13.1 seaborn-0.13.2 stevedore-5.2.0 symengine-0.11.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting qiskit_aer
#   Using cached qiskit_aer-0.14.2-cp310-cp310-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=0.45.2 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit_aer) (1.0.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit_aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit_aer) (1.13.1)
# Requirement already satisfied: psutil>=5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit_aer) (5.9.8)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (0.14.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (1.12.1)
# Requirement already satisfied: dill>=0.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (2.9.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=0.45.2->qiskit_aer) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from python-dateutil>=2.8.0->qiskit>=0.45.2->qiskit_aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from stevedore>=3.0.0->qiskit>=0.45.2->qiskit_aer) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from sympy>=1.3->qiskit>=0.45.2->qiskit_aer) (1.3.0)
# Using cached qiskit_aer-0.14.2-cp310-cp310-win_amd64.whl (9.5 MB)
# Installing collected packages: qiskit_aer
# Successfully installed qiskit_aer-0.14.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting qiskit_ibm_runtime
#   Using cached qiskit_ibm_runtime-0.23.0-py3-none-any.whl.metadata (19 kB)
# Collecting requests>=2.19 (from qiskit_ibm_runtime)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime)
#   Using cached requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.13 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit_ibm_runtime) (1.26.4)
# Collecting urllib3>=1.21.1 (from qiskit_ibm_runtime)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit_ibm_runtime) (2.9.0)
# Collecting websocket-client>=1.5.1 (from qiskit_ibm_runtime)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting ibm-platform-services>=0.22.6 (from qiskit_ibm_runtime)
#   Using cached ibm_platform_services-0.53.7-py3-none-any.whl
# Collecting pydantic (from qiskit_ibm_runtime)
#   Using cached pydantic-2.7.3-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: qiskit>=1.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit_ibm_runtime) (1.0.2)
# Collecting ibm-cloud-sdk-core<4.0.0,>=3.19.2 (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Using cached ibm_cloud_sdk_core-3.20.1-py3-none-any.whl
# Requirement already satisfied: six>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.14.2)
# Requirement already satisfied: scipy>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (1.12.1)
# Requirement already satisfied: dill>=0.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit>=1.0.0->qiskit_ibm_runtime) (0.11.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19->qiskit_ibm_runtime)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19->qiskit_ibm_runtime)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19->qiskit_ibm_runtime)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting cryptography>=1.3 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Using cached cryptography-42.0.8-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Using cached pyspnego-0.10.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting annotated-types>=0.4.0 (from pydantic->qiskit_ibm_runtime)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.18.4 (from pydantic->qiskit_ibm_runtime)
#   Using cached pydantic_core-2.18.4-cp310-none-win_amd64.whl.metadata (6.7 kB)
# Collecting cffi>=1.12 (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Using cached cffi-1.16.0-cp310-cp310-win_amd64.whl.metadata (1.5 kB)
# Collecting requests>=2.19 (from qiskit_ibm_runtime)
#   Using cached requests-2.32.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting PyJWT<3.0.0,>=2.8.0 (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit_ibm_runtime)
#   Using cached PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting sspilib>=0.1.0 (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Using cached sspilib-0.1.0-cp310-cp310-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from stevedore>=3.0.0->qiskit>=1.0.0->qiskit_ibm_runtime) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from sympy>=1.3->qiskit>=1.0.0->qiskit_ibm_runtime) (1.3.0)
# Collecting pycparser (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Using cached qiskit_ibm_runtime-0.23.0-py3-none-any.whl (3.0 MB)
# Using cached requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached pydantic-2.7.3-py3-none-any.whl (409 kB)
# Using cached pydantic_core-2.18.4-cp310-none-win_amd64.whl (1.9 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-win_amd64.whl (100 kB)
# Using cached cryptography-42.0.8-cp39-abi3-win_amd64.whl (2.9 MB)
# Using cached requests-2.32.2-py3-none-any.whl (63 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached pyspnego-0.10.2-py3-none-any.whl (129 kB)
# Using cached cffi-1.16.0-cp310-cp310-win_amd64.whl (181 kB)
# Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Using cached sspilib-0.1.0-cp310-cp310-win_amd64.whl (563 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: websocket-client, urllib3, sspilib, PyJWT, pydantic-core, pycparser, idna, charset-normalizer, certifi, annotated-types, requests, pydantic, cffi, ibm-cloud-sdk-core, cryptography, pyspnego, ibm-platform-services, requests-ntlm, qiskit_ibm_runtime
# Successfully installed PyJWT-2.8.0 annotated-types-0.7.0 certifi-2024.6.2 cffi-1.16.0 charset-normalizer-3.3.2 cryptography-42.0.8 ibm-cloud-sdk-core-3.20.1 ibm-platform-services-0.53.7 idna-3.7 pycparser-2.22 pydantic-2.7.3 pydantic-core-2.18.4 pyspnego-0.10.2 qiskit_ibm_runtime-0.23.0 requests-2.32.2 requests-ntlm-1.3.0 sspilib-0.1.0 urllib3-2.2.1 websocket-client-1.8.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pylatexenc in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (2.10)
# Note: you may need to restart the kernel to use updated packages.
# Collecting qiskit-transpiler-service
#   Using cached qiskit_transpiler_service-0.4.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: qiskit~=1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-transpiler-service) (1.0.2)
# Collecting backoff~=2.0 (from qiskit-transpiler-service)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting qiskit-qasm3-import~=0.4 (from qiskit-transpiler-service)
#   Using cached qiskit_qasm3_import-0.4.2-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: requests~=2.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-transpiler-service) (2.32.2)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.14.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (1.12.1)
# Requirement already satisfied: dill>=0.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (2.9.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit~=1.0->qiskit-transpiler-service) (0.11.0)
# Collecting openqasm3<0.6,>=0.4 (from openqasm3[parser]<0.6,>=0.4->qiskit-qasm3-import~=0.4->qiskit-transpiler-service)
#   Using cached openqasm3-0.5.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests~=2.0->qiskit-transpiler-service) (2024.6.2)
# Collecting antlr4-python3-runtime<4.14,>=4.7 (from openqasm3[parser]<0.6,>=0.4->qiskit-qasm3-import~=0.4->qiskit-transpiler-service)
#   Using cached antlr4_python3_runtime-4.13.1-py3-none-any.whl.metadata (304 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from python-dateutil>=2.8.0->qiskit~=1.0->qiskit-transpiler-service) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from stevedore>=3.0.0->qiskit~=1.0->qiskit-transpiler-service) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from sympy>=1.3->qiskit~=1.0->qiskit-transpiler-service) (1.3.0)
# Using cached qiskit_transpiler_service-0.4.3-py3-none-any.whl (25 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached qiskit_qasm3_import-0.4.2-py3-none-any.whl (27 kB)
# Using cached openqasm3-0.5.0-py3-none-any.whl (524 kB)
# Using cached antlr4_python3_runtime-4.13.1-py3-none-any.whl (144 kB)
# Installing collected packages: openqasm3, antlr4-python3-runtime, backoff, qiskit-qasm3-import, qiskit-transpiler-service
# Successfully installed antlr4-python3-runtime-4.13.1 backoff-2.2.1 openqasm3-0.5.0 qiskit-qasm3-import-0.4.2 qiskit-transpiler-service-0.4.3
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/qiskit-community/Quantum-Challenge-Grader.git
#   Cloning https://github.com/qiskit-community/Quantum-Challenge-Grader.git to c:\users\anshu\appdata\local\temp\pip-req-build-c_i7xnwh
#   Resolved https://github.com/qiskit-community/Quantum-Challenge-Grader.git to commit 95854ae37d9e64dd77bf73fdfaf54be95b0b300f
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting typeguard (from qc_grader==0.18.11)
#   Using cached typeguard-4.3.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting jsonpickle==3.0.3 (from qc_grader==0.18.11)
#   Using cached jsonpickle-3.0.3-py3-none-any.whl.metadata (7.3 kB)
# Collecting ipycytoscape (from qc_grader==0.18.11)
#   Using cached ipycytoscape-1.3.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting plotly (from qc_grader==0.18.11)
#   Using cached plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting networkx==3.2.1 (from qc_grader==0.18.11)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting graphviz (from qc_grader==0.18.11)
#   Using cached graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: qiskit==1.0.2 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit[visualization]==1.0.2->qc_grader==0.18.11) (1.0.2)
# Requirement already satisfied: qiskit-ibm-runtime in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qc_grader==0.18.11) (0.23.0)
# Requirement already satisfied: qiskit-aer in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qc_grader==0.18.11) (0.14.2)
# Requirement already satisfied: qiskit-transpiler-service in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qc_grader==0.18.11) (0.4.3)
# Collecting qiskit-serverless==0.12.0 (from qc_grader==0.18.11)
#   Using cached qiskit_serverless-0.12.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting circuit-knitting-toolbox (from qc_grader==0.18.11)
#   Using cached circuit_knitting_toolbox-0.7.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (0.14.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (1.13.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (1.12.1)
# Requirement already satisfied: dill>=0.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (2.9.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (4.12.2)
# Requirement already satisfied: symengine>=0.11 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (0.11.0)
# Collecting ray<3,>=2.9.3 (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached ray-2.20.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.32.2 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-serverless==0.12.0->qc_grader==0.18.11) (2.32.2)
# Requirement already satisfied: importlib-metadata>=5.2.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-serverless==0.12.0->qc_grader==0.18.11) (7.1.0)
# Collecting qiskit-ibm-provider>=0.10.0 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached qiskit_ibm_provider-0.11.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting cloudpickle==2.2.1 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting tqdm>=4.66.3 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting opentelemetry-api>=1.18.0 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_api-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk>=1.18.0 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_sdk-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.18.0 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting s3fs>=2023.6.0 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached s3fs-2024.6.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry.instrumentation.requests>=0.40b0 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_instrumentation_requests-0.46b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting ipywidgets>=8.1.2 (from qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: ipython>=8.10.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-serverless==0.12.0->qc_grader==0.18.11) (8.25.0)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit[visualization]==1.0.2->qc_grader==0.18.11) (3.9.0)
# Requirement already satisfied: pydot in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit[visualization]==1.0.2->qc_grader==0.18.11) (2.0.0)
# Requirement already satisfied: Pillow>=4.2.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit[visualization]==1.0.2->qc_grader==0.18.11) (10.3.0)
# Requirement already satisfied: pylatexenc>=1.4 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit[visualization]==1.0.2->qc_grader==0.18.11) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit[visualization]==1.0.2->qc_grader==0.18.11) (0.13.2)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-ibm-runtime->qc_grader==0.18.11) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-ibm-runtime->qc_grader==0.18.11) (2.2.1)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-ibm-runtime->qc_grader==0.18.11) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-ibm-runtime->qc_grader==0.18.11) (0.53.7)
# Requirement already satisfied: pydantic in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-ibm-runtime->qc_grader==0.18.11) (2.7.3)
# Requirement already satisfied: psutil>=5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-aer->qc_grader==0.18.11) (5.9.8)
# Collecting spectate>=1.0.0 (from ipycytoscape->qc_grader==0.18.11)
#   Using cached spectate-1.0.1-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting tenacity>=6.2.0 (from plotly->qc_grader==0.18.11)
#   Using cached tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from plotly->qc_grader==0.18.11) (24.0)
# Requirement already satisfied: backoff~=2.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-transpiler-service->qc_grader==0.18.11) (2.2.1)
# Requirement already satisfied: qiskit-qasm3-import~=0.4 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from qiskit-transpiler-service->qc_grader==0.18.11) (0.4.2)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.19.2 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime->qc_grader==0.18.11) (3.20.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from importlib-metadata>=5.2.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (3.19.2)
# Requirement already satisfied: decorator in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (3.0.46)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (5.14.3)
# Requirement already satisfied: exceptiongroup in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (1.2.0)
# Requirement already satisfied: colorama in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ipywidgets>=8.1.2->qiskit-serverless==0.12.0->qc_grader==0.18.11) (0.2.2)
# Collecting widgetsnbextension~=4.0.11 (from ipywidgets>=8.1.2->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached widgetsnbextension-4.0.11-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.11 (from ipywidgets>=8.1.2->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached jupyterlab_widgets-3.0.11-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (3.1.2)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.18.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached googleapis_common_protos-1.63.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting grpcio<2.0.0,>=1.0.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached grpcio-1.64.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_proto-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf<5.0,>=3.19 (from opentelemetry-proto==1.25.0->opentelemetry-exporter-otlp-proto-grpc>=1.18.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting opentelemetry-instrumentation==0.46b0 (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_instrumentation-0.46b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.46b0 (from opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opentelemetry_util_http-0.46b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (70.0.0)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.46b0->opentelemetry.instrumentation.requests>=0.40b0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached wrapt-1.16.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from python-dateutil>=2.8.0->qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (1.16.0)
# Collecting websockets>=10.0 (from qiskit-ibm-provider>=0.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached websockets-12.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: openqasm3<0.6,>=0.4 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from openqasm3[parser]<0.6,>=0.4->qiskit-qasm3-import~=0.4->qiskit-transpiler-service->qc_grader==0.18.11) (0.5.0)
# Collecting click>=7.0 (from ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting filelock (from ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting jsonschema (from ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached msgpack-1.0.8-cp310-cp310-win_amd64.whl.metadata (9.4 kB)
# Collecting pyyaml (from ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting aiosignal (from ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist (from ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: pandas>=1.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11) (2.2.2)
# Collecting pyarrow>=6.0.1 (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached pyarrow-16.1.0-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting fsspec (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached fsspec-2024.6.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp>=3.7 (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached aiohttp-3.9.5-cp310-cp310-win_amd64.whl.metadata (7.7 kB)
# Collecting aiohttp-cors (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting py-spy>=0.2.0 (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached py_spy-0.3.14-py2.py3-none-win_amd64.whl.metadata (16 kB)
# Collecting opencensus (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting prometheus-client>=0.7.1 (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting smart-open (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached virtualenv-20.26.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from pydantic->qiskit-ibm-runtime->qc_grader==0.18.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from pydantic->qiskit-ibm-runtime->qc_grader==0.18.11) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests>=2.32.2->qiskit-serverless==0.12.0->qc_grader==0.18.11) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests>=2.32.2->qiskit-serverless==0.12.0->qc_grader==0.18.11) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests>=2.32.2->qiskit-serverless==0.12.0->qc_grader==0.18.11) (2024.6.2)
# Requirement already satisfied: cryptography>=1.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc_grader==0.18.11) (42.0.8)
# Requirement already satisfied: pyspnego>=0.4.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc_grader==0.18.11) (0.10.2)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs>=2023.6.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached aiobotocore-2.13.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from stevedore>=3.0.0->qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (6.0.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from sympy>=1.3->qiskit==1.0.2->qiskit[visualization]==1.0.2->qc_grader==0.18.11) (1.3.0)
# Collecting botocore<1.34.107,>=1.34.70 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached botocore-1.34.106-py3-none-any.whl.metadata (5.7 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached aioitertools-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl.metadata (32 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp>=3.7->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc_grader==0.18.11) (1.16.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.19.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime->qc_grader==0.18.11) (2.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from jedi>=0.16->ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (0.8.4)
# Requirement already satisfied: antlr4-python3-runtime<4.14,>=4.7 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from openqasm3[parser]<0.6,>=0.4->qiskit-qasm3-import~=0.4->qiskit-transpiler-service->qc_grader==0.18.11) (4.13.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from pandas>=1.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from pandas>=1.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11) (2024.1)
# Requirement already satisfied: wcwidth in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (0.2.13)
# Requirement already satisfied: sspilib>=0.1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc_grader==0.18.11) (0.1.0)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11) (4.2.2)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->ray<3,>=2.9.3->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached rpds_py-0.18.1-cp310-none-win_amd64.whl.metadata (4.2 kB)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached google_api_core-2.19.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from stack-data->ipython>=8.10.0->qiskit-serverless==0.12.0->qc_grader==0.18.11) (0.2.2)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.34.107,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.6.0->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pycparser in c:\users\anshu\highschool\quantumchallenge2024\ibm-quantum-challenge-2024\.conda\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime->qc_grader==0.18.11) (2.22)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached google_auth-2.30.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,default]<3,>=2.9.3->qiskit-serverless==0.12.0->qc_grader==0.18.11)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Using cached jsonpickle-3.0.3-py3-none-any.whl (40 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached qiskit_serverless-0.12.0-py3-none-any.whl (42 kB)
# Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Using cached circuit_knitting_toolbox-0.7.2-py3-none-any.whl (134 kB)
# Using cached graphviz-0.20.3-py3-none-any.whl (47 kB)
# Using cached ipycytoscape-1.3.3-py2.py3-none-any.whl (3.6 MB)
# Using cached plotly-5.22.0-py3-none-any.whl (16.4 MB)
# Using cached typeguard-4.3.0-py3-none-any.whl (35 kB)
# Using cached ipywidgets-8.1.3-py3-none-any.whl (139 kB)
# Using cached opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
# Using cached opentelemetry_instrumentation_requests-0.46b0-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Using cached opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
# Using cached opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
# Using cached qiskit_ibm_provider-0.11.0-py3-none-any.whl (249 kB)
# Using cached ray-2.20.0-cp310-cp310-win_amd64.whl (25.7 MB)
# Using cached s3fs-2024.6.0-py3-none-any.whl (29 kB)
# Using cached fsspec-2024.6.0-py3-none-any.whl (176 kB)
# Using cached spectate-1.0.1-py2.py3-none-any.whl (11 kB)
# Using cached tenacity-8.3.0-py3-none-any.whl (25 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached aiobotocore-2.13.0-py3-none-any.whl (76 kB)
# Using cached aiohttp-3.9.5-cp310-cp310-win_amd64.whl (370 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached frozenlist-1.4.1-cp310-cp310-win_amd64.whl (50 kB)
# Using cached googleapis_common_protos-1.63.1-py2.py3-none-any.whl (229 kB)
# Using cached grpcio-1.64.1-cp310-cp310-win_amd64.whl (4.1 MB)
# Using cached jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
# Using cached msgpack-1.0.8-cp310-cp310-win_amd64.whl (75 kB)
# Using cached prometheus_client-0.20.0-py3-none-any.whl (54 kB)
# Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
# Using cached py_spy-0.3.14-py2.py3-none-win_amd64.whl (1.4 MB)
# Using cached pyarrow-16.1.0-cp310-cp310-win_amd64.whl (25.9 MB)
# Using cached virtualenv-20.26.2-py3-none-any.whl (3.9 MB)
# Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Using cached websockets-12.0-cp310-cp310-win_amd64.whl (124 kB)
# Using cached widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
# Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Using cached colorful-0.5.6-py2.py3-none-any.whl (201 kB)
# Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Using cached opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
# Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Using cached smart_open-7.0.4-py3-none-any.whl (61 kB)
# Using cached aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached botocore-1.34.106-py3-none-any.whl (12.2 MB)
# Using cached distlib-0.3.8-py2.py3-none-any.whl (468 kB)
# Using cached google_api_core-2.19.0-py3-none-any.whl (139 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached multidict-6.0.5-cp310-cp310-win_amd64.whl (28 kB)
# Using cached opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.18.1-cp310-none-win_amd64.whl (209 kB)
# Using cached wrapt-1.16.0-cp310-cp310-win_amd64.whl (37 kB)
# Using cached yarl-1.9.4-cp310-cp310-win_amd64.whl (76 kB)
# Using cached google_auth-2.30.0-py2.py3-none-any.whl (193 kB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached proto_plus-1.23.0-py3-none-any.whl (48 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Building wheels for collected packages: qc_grader
#   Building wheel for qc_grader (setup.py): started
#   Building wheel for qc_grader (setup.py): finished with status 'done'
#   Created wheel for qc_grader: filename=qc_grader-0.18.11-py3-none-any.whl size=34054 sha256=3800b79ff489312c924352047e053e7401f1c28cb65374e38f8a2450a51dd05b
#   Stored in directory: C:\Users\anshu\AppData\Local\Temp\pip-ephem-wheel-cache-gn7fv497\wheels\7e\67\91\88d6a5b4dd4beb318ed4e79c807e2be98b7d3c2ea66565a116
# Successfully built qc_grader
# Installing collected packages: py-spy, opencensus-context, distlib, wrapt, widgetsnbextension, websockets, typeguard, tqdm, tenacity, spectate, rpds-py, pyyaml, pyasn1, pyarrow, protobuf, prometheus-client, opentelemetry-util-http, networkx, multidict, msgpack, jupyterlab-widgets, jsonpickle, jmespath, grpcio, graphviz, fsspec, frozenlist, filelock, colorful, cloudpickle, click, cachetools, attrs, async-timeout, aioitertools, yarl, virtualenv, smart-open, rsa, referencing, pyasn1-modules, proto-plus, plotly, opentelemetry-proto, googleapis-common-protos, deprecated, botocore, aiosignal, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, jsonschema-specifications, google-auth, aiohttp, opentelemetry-semantic-conventions, opentelemetry-instrumentation, jsonschema, ipywidgets, google-api-core, aiohttp-cors, aiobotocore, s3fs, ray, qiskit-ibm-provider, opentelemetry-sdk, opentelemetry.instrumentation.requests, opencensus, ipycytoscape, opentelemetry-exporter-otlp-proto-grpc, circuit-knitting-toolbox, qiskit-serverless, qc_grader
# Successfully installed aiobotocore-2.13.0 aiohttp-3.9.5 aiohttp-cors-0.7.0 aioitertools-0.11.0 aiosignal-1.3.1 async-timeout-4.0.3 attrs-23.2.0 botocore-1.34.106 cachetools-5.3.3 circuit-knitting-toolbox-0.7.2 click-8.1.7 cloudpickle-2.2.1 colorful-0.5.6 deprecated-1.2.14 distlib-0.3.8 filelock-3.14.0 frozenlist-1.4.1 fsspec-2024.6.0 google-api-core-2.19.0 google-auth-2.30.0 googleapis-common-protos-1.63.1 graphviz-0.20.3 grpcio-1.64.1 ipycytoscape-1.3.3 ipywidgets-8.1.3 jmespath-1.0.1 jsonpickle-3.0.3 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 jupyterlab-widgets-3.0.11 msgpack-1.0.8 multidict-6.0.5 networkx-3.2.1 opencensus-0.11.4 opencensus-context-0.1.3 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-instrumentation-0.46b0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 opentelemetry-util-http-0.46b0 opentelemetry.instrumentation.requests-0.46b0 plotly-5.22.0 prometheus-client-0.20.0 proto-plus-1.23.0 protobuf-4.25.3 py-spy-0.3.14 pyarrow-16.1.0 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyyaml-6.0.1 qc_grader-0.18.11 qiskit-ibm-provider-0.11.0 qiskit-serverless-0.12.0 ray-2.20.0 referencing-0.35.1 rpds-py-0.18.1 rsa-4.9 s3fs-2024.6.0 smart-open-7.0.4 spectate-1.0.1 tenacity-8.3.0 tqdm-4.66.4 typeguard-4.3.0 virtualenv-20.26.2 websockets-12.0 widgetsnbextension-4.0.11 wrapt-1.16.0 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/qiskit-community/Quantum-Challenge-Grader.git 'C:\Users\anshu\AppData\Local\Temp\pip-req-build-c_i7xnwh'

# %%
### Save API Token, if needed

# %set_env QXToken=6243dd03083fc5ab7c53ec641194b0706ce1c9b40874100520b46d46b7898c656bfd26ccc559996bd8f67311a55eff7c8695c12eb11caa819ae2a4864ece7da2

# Make sure there is no space between the equal sign
# and the beginning of your token
# Out:
# env: QXToken=6243dd03083fc5ab7c53ec641194b0706ce1c9b40874100520b46d46b7898c656bfd26ccc559996bd8f67311a55eff7c8695c12eb11caa819ae2a4864ece7da2

# %%
# imports
import numpy as np
from typing import List, Callable
from scipy.optimize import minimize
from scipy.optimize._optimize import OptimizeResult
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, Operator, SparsePauliOp
from qiskit.primitives import StatevectorSampler, PrimitiveJob
from qiskit.circuit.library import TwoLocal
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime.fake_provider import FakeSherbrooke
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator

# %%
# Setup the grader
from qc_grader.challenges.iqc_2024 import (
    grade_lab1_ex1,
    grade_lab1_ex2,
    grade_lab1_ex3,
    grade_lab1_ex4,
    grade_lab1_ex5,
    grade_lab1_ex6,
    grade_lab1_ex7,
)

# %% [markdown]
# ## Introduction <a name="intro"></a>

# %% [markdown]
# Welcome to lab one! This lab is designed to introduce you to some of the new capabilities and functions of Qiskit 1.0. Later challenges will develop on these capabilities further and introduce the more complex new Qiskit functionalities.
#
# Through this lab you will learn how to set up quantum states using Qiskit, and how to implement an optimization algorithm using VQE. These two tasks will be set in two sections:
#
#
# 1.   Qiskit states, the new and the old
# 2.   VQE with Qiskit 1.0
#
# Let's get started!

# %% [markdown]
# ## Part I: Qiskit states, the new and the old  <a name="pt1"></a>

# %% [markdown]
# <a id="exercise1"></a>
# <a name="exercise1"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 1: Create and draw a singlet Bell state circuit</b>
#
# Bell circuits are specific circuits which generate Bell states, or EPR pairs, a form of entangled and normalized basis vectors. In other words, they are the circuits we use to generate entangled states, a key ingredient in quantum computations.
#
# There exist 4 different Bell states. You can learn about each from the [Basics of Quantum Information page](https://learning.quantum.ibm.com/course/basics-of-quantum-information/multiple-systems#bell-states)
#
# **Your Task:** please build a circuit that generates the $| \psi ^- \rangle$ Bell state.
#
# </div>

# %%
# Build a circuit to form a psi-minus Bell state
# Apply gates to the provided QuantumCircuit, qc

qc = QuantumCircuit(2)

### Write your code below here ###
qc.h(0)
qc.cx(0, 1)
qc.x(1)
qc.z(1)


### Don't change any code past this line ###
qc.measure_all()
qc.draw('mpl')

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Hint:** The $| \psi ^- \rangle$ Bell state uses a single Z gate, and a single X gate, both of which occur after the CNOT.
#
# </div>

# %%
# Submit your answer using following code

grade_lab1_ex1(qc) # Expected result type: QuantumCircuit
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# To observe the resulting entangled state that this circuit produces, we'll run our circuit a number of times and collect statistics on the final qubit measurements. That is the goal of the next exercise.

# %% [markdown]
# <a id="exercise2"></a>
# <a name="exercise2"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 2: Use Sampler.run</b>
#
# The [Qiskit Sampler](https://docs.quantum.ibm.com/api/qiskit/qiskit.primitives.StatevectorSampler) primitive ([more info on Primitives here](https://docs.quantum.ibm.com/run/primitives-get-started)) returns the sampled result according to the specified output type. It allows us to efficiently sample quantum states by executing quantum circuits and providing probability distributions of the quantum states.
#
# **Your Task:** use the Qiskit StatevectorSampler to obtain the counts resulting from our circuit.
#
# </div>

# %%
qc.measure_all()

### Write your code below here ###
sampler = StatevectorSampler()
pub = (qc)
job_sampler = sampler.run([pub], shots=256)


### Don't change any code past this line ###

result_sampler = job_sampler.result()
counts_sampler = result_sampler[0].data.meas.get_counts()

print(counts_sampler)
# Out:
# {'10': 124, '01': 132}

# %%
# Submit your answer using following code

grade_lab1_ex2(job_sampler) # Expected result type: PrimitiveJob
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %%
plot_histogram(counts_sampler)

# %% [markdown]
# The histogram shows an approximately even probability of finding our qubits in the `01` and the `10` states, suggesting that entanglement was performed as expected.

# %% [markdown]
# <a id="exercise3"></a>
# <a name="exercise3"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 3: Create and draw a W-state circuit</b>
#
# Next, we will develop a slightly more complicated circuit. Similarly to Bell states circuit producing Bell states, W-state circuits produce W states. Although Bell states entangle two qubits, W-states entangle three qubits.
# To build our W-state, we will follow 6 simple steps:
#
# 1.  Initialize our 3 qubit circuit
# 2.  Perform an Ry rotation on our qubit. The specifics of this operation are provided.
# 3.  Perform a controlled hadamard gate on qubit 1, with control qubit 0
# 4.  Add a CNOT gate with control qubit 1 and target qubit 2
# 5.  Add a CNOT gate with control qubit 0 and target qubit 1
# 6.  Add a X gate on qubit 0
#
# **Your Task:** Follow the steps to build the W-state circuit
#
# </div>

# %%
# Step 1
qc = QuantumCircuit(3)

# Step 2 (provided)
qc.ry(1.91063324, 0)

# Add steps 3-6 below
qc.ch(0, 1)
qc.cx(1, 2)
qc.cx(0, 1)
qc.x(0)


### Don't change any code past this line ###
qc.measure_all()
qc.draw('mpl')

# %%
# Submit your answer using following code

grade_lab1_ex3(qc) # Expected result type: # Expected result type: QuantumCircuit
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# Once again, let's visualize our results:

# %%
sampler = StatevectorSampler()
pub = (qc)
job_sampler = sampler.run([pub], shots=10000)

result_sampler = job_sampler.result()
counts_sampler = result_sampler[0].data.meas.get_counts()

print(counts_sampler)
# Out:
# {'010': 3319, '100': 3364, '001': 3317}

# %%
plot_histogram(counts_sampler)

# %% [markdown]
# We observe our total counts distributed in three similarly sized bins in three states, which are the three desired states for the successful creation of a W-state. Good work!
#
# Now that we have basic circuits down, we'll start introducing and developing more complex codes with Qiskit 1.0.

# %% [markdown]
# ## Part II: VQE with Qiskit 1.0
# <a name="pt2"></a>

# %% [markdown]
# The core of this challenge will leverage Qiskit Runtime and a Variational Quantum Eigensolver (VQE). We will be using the Qiskit Runtime Estimator to calculate expectation values for combinations of qubits, and Qiskit Runtime Sessions to facilitate running a VQE algorithm. The challenge draws upon code from an example that experimental physicist & IBM Quantum researcher Nick Bronn created for the [Coding with Qiskit Runtime video series](https://www.youtube.com/playlist?list=PLOFEBzvs-VvqAC8DnVoLOzg2bKE4C7ARM), specifically in [Episode 05 Primitives & Sessions](https://youtu.be/yxuH8eb4MS4?si=e3trSORNjooWlQXu), and implements it using the newest Qiskit 1.0 version.

# %% [markdown]
# ### Let's start by creating a Pauli operator
# A Pauli operator is a matrix representing a quantum mechanical observable corresponding to a measurement of spin along a particular axis (x, y, z). Let's build one:

# %%
pauli_op = SparsePauliOp(['ZII', 'IZI', 'IIZ'])
print(pauli_op.to_matrix())
# Out:
# [[ 3.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  1.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j  0.+0.j -3.+0.j]]

# %% [markdown]
# Feel free to experiment with various Pauli operators and see what resulting possible combinantions you obtain!

# %% [markdown]
# ### Setup and run a VQE algorithm

# %% [markdown]
# Now, we'll start setting up our VQE algorithm. Variational quantum eigensolvers (VQEs), are hybrid algorithms that utilize quantum and classical techniques to find the ground state of a given physical system. They are often used in quantum chemistry and optimization problems, and are promising candidates for hybrid-algorithms in noisy near-term devices.

# %% [markdown]
# VQEs are characterized by the use of a classical optimization algorithm to iteratively improve upon a parameterized trial solution, called an "ansatz". The aim is to solve for the ground state of a given Hamiltonian represented as a linear combination of Pauli terms.

# %% [markdown]
# Executing a VQE algorithm requires these three steps:
#
# 1. Setting up the Hamiltonian and ansatz (problem specification)
# 2. Implementing the Qiskit Runtime estimator
# 3. Adding the Classical optimizer and running our program
#
# We we will follow these steps.

# %% [markdown]
# <a id="exercise4"></a>
# <a name="exercise4"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 4: Create a parameterized circuit to serve as the ansatz</b>
#
# Our first task will be to set up our ansatz, or a trial solution, for our problem which we will compare against.
#
# For this we can use Qiskit's `TwoLocal` circuit, a pre-built circuit that can be used to prepare trial wave functions for variational quantum algorithms or classification circuits for machine learning. TwoLocal circuits are parameterized circuits consisting of alternating rotation layers and entanglement layers. You can find more information about them in [Qiskit's documentation](https://docs.quantum.ibm.com/api/qiskit/circuit_library).
#
# **Your Task:** Set up a 3-qubit TwoLocal circuit using [Ry](https://docs.quantum.ibm.com/api/qiskit/qiskit.circuit.library.RYGate) and [Rz](https://docs.quantum.ibm.com/api/qiskit/qiskit.circuit.library.RZGate) rotations. Entanglement should be set to full, and entanglement blocks should use the Cz gate. Make sure you set `reps=1` and `insert_barriers=True`.
#
# </div>

# %%
num_qubits = 3
rotation_blocks = ['ry', 'rz']
entanglement_blocks = 'cz'
entanglement = 'full'

ansatz = TwoLocal(num_qubits, rotation_blocks, entanglement_blocks, entanglement, reps=1, insert_barriers=True)


### Don't change any code past this line ###
ansatz.decompose().draw('mpl')

# %%
# Submit your answer using following code

grade_lab1_ex4(num_qubits, rotation_blocks, entanglement_blocks, entanglement) # Expected result type: int, List[str], str, str
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# From the previous figure we see that our ansatz circuit is defined by a vector of parameters θ, with the total number given by:

# %%
num_params = ansatz.num_parameters
num_params
# Out:
# 12

# %% [markdown]
# <a id="exercise5"></a>
# <a name="exercise5"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 5: Transpile to ISA circuits </b>
#
# In this example we will use the [FakeSherbrooke](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.fake_provider.FakeSherbrooke), a fake  (simulated) 127-qubit backend, useful for testing the transpiler and other backend-facing functionalities.
#
# Preset pass managers are the default pass managers used by the `transpile()` function. `transpile()` provides a convenient and simple method to construct a standalone `PassManager` object that mirrors what the transpile function does when optimizing and transforming a quantum circuit for execution on a specific backend.
#
# **Your Task:** Define the pass manager. Reference the [Qiskit documentation](https://docs.quantum.ibm.com/api/qiskit/0.42/qiskit.transpiler.preset_passmanagers.generate_preset_pass_manager) for more info.
#
#
# </div>

# %%
backend_answer = FakeSherbrooke()
optimization_level_answer = 3
pm = generate_preset_pass_manager(backend=backend_answer,optimization_level=optimization_level_answer)
isa_circuit = pm.run(ansatz)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Tip: Make sure you are using the right backend! </b>
#
# The grader was designed with **FakeSherbrooke** in mind, and therefore is expecting a 127 qubit map. If you use another backend you might encounter issues.
#
#
# </div>

# %%
# Submit your answer using following code

grade_lab1_ex5(isa_circuit) # Expected result type: QuantumCircuit
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# With the newest version of Qiskit Runtime, all circuits submitted to a backend must conform to the constraints of the backend’s Target. Such circuits are considered to be written in terms of that backend’s Instruction Set Architecture ([ISA](https://www.ibm.com/quantum/blog/isa-circuits?social_post=sf187802680&sf187802680=1)) — i.e., the set of instructions the device can understand and execute. These Target constraints are defined by factors like the device’s native basis gates, its qubit connectivity, and when relevant, its pulse and other instruction timing specifications.
# To visualize our ISA circuits we can run:

# %%
isa_circuit.draw('mpl', idle_wires=False,)

# %% [markdown]
# As you can see, after transpilation, the circuit only contain the native basis gates of the backend. For more details on ISA circuits check out these resources from the IBM team:
#
# - [What are ISA circuits?](https://www.ibm.com/quantum/blog/isa-circuits)
# - [Understanding the new ISA circuits requirement](https://docs.quantum.ibm.com/announcements/news/2024-05-06-ISA-circuit-requirement#understanding-the-new-isa-circuits-requirement)
#
# You can run the next cell to define our Hamiltonian, then move on to Exercise 6.

# %%
# Define our Hamiltonian
hamiltonian_isa = pauli_op.apply_layout(layout=isa_circuit.layout)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Tip: For the following two exercises make sure you are working with Qiskit 1.0.2! </b>
#
# You can download this version using: **%pip install qiskit==1.0.2**
#
#
# </div>

# %% [markdown]
# <a id="exercise6"></a>
# <a name="exercise6"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 6: Defining the cost function </b>
#
# Like many classical optimization problems, the solution to a VQE problem can be formulated as minimization of a scalar cost function. The cost function for our VQE is simple: the energy!
#
# **Your Task:** Define a cost function by using Qiskit Runtime Estimator to find the energy for a given parameterized state and our Hamiltonian.
#
# </div>

# %%
def cost_func(params, ansatz, hamiltonian, estimator, callback_dict):
    """Return estimate of energy from estimator

    Parameters:
        params (ndarray): Array of ansatz parameters
        ansatz (QuantumCircuit): Parameterized ansatz circuit
        hamiltonian (SparsePauliOp): Operator representation of Hamiltonian
        estimator (EstimatorV2): Estimator primitive instance

    Returns:
        float: Energy estimate
    """
    pub = (ansatz, [hamiltonian], [params])
    result = estimator.run(pubs=[pub]).result()
    energy = result[0].data.evs[0]

    callback_dict["iters"] += 1
    callback_dict["prev_vector"] = params
    callback_dict["cost_history"].append(energy)


### Don't change any code past this line ###
    print(energy)
    return energy, result

# %%
# Submit your answer using following code

grade_lab1_ex6(cost_func) # Expected result type: Callable
# Out:
# [0.64404297]
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# Callback functions are a standard way for users to obtain additional information about the status of an iterative algorithm (such as VQE). However, it is possible to do much more than this. Here, we use a mutable object (dictionary), to store resulting vector at each iteration of our algorithm, in case we need to restart the routine due to failure or return the another iteration number.

# %%
callback_dict = {
    "prev_vector": None,
    "iters": 0,
    "cost_history": [],
}

# %% [markdown]
# ### Using the Classical Optimizer

# %% [markdown]
# We can now use a classical optimizer of our choice to minimize the cost function.
# In real quantum hardware, the choice of optimizer is important, as not all optimizers handle noisy cost function landscapes equally well. Here, we can use SciPy routines.
#
# To begin the routine, we specify a random initial set of parameters:

# %%
x0 = 2 * np.pi * np.random.random(num_params)
x0
# Out:
# array([1.86184989, 3.67182492, 5.07449409, 0.84285059, 2.03050361,
#        1.38698093, 2.70482249, 6.2565821 , 5.20338959, 3.46860818,
#        4.38307192, 2.90483376])

# %% [markdown]
# <a id="exercise7"></a>
# <a name="exercise7"></a>
# <div class="alert alert-block alert-success">
#
# <b> Exercise 7: QiskitRuntimeService V2 Primitives, local testing mode and Sessions, a first look </b>
#
#
# Next, we will use the new QiskitRuntimeService [V2 primitives](https://docs.quantum.ibm.com/api/migration-guides/v2-primitives): [EstimatorV2](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.EstimatorV2) and [SamplerV2](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/qiskit_ibm_runtime.SamplerV2).
#
# The new Estimator interface lets you specify a single circuit and multiple observables and parameter value sets for that circuit, so that sweeps over parameter value sets and observables can be efficiently specified. Previously, you had to specify the same circuit multiple times to match the size of the data to be combined. Also, while you can still use optimization_level and resilience_level as the simple knobs, V2 primitives give you the flexibility to turn on or off individual error mitigation / suppression methods to customize them for your needs.
#
# SamplerV2 is simplified to focus on its core task of sampling the quantum register from the execution of quantum circuits. It returns the samples, whose type is defined by the program, without weights. The output data is also separated by the output register names defined by the program. This change enables future support for circuits with classical control flow.
#
# We will also use Qiskit's 1.0 [local testing mode](https://docs.quantum.ibm.com/verify/local-testing-mode). Local testing mode (available with qiskit-ibm-runtime 0.22.0 or later) can be used to help develop and test programs before fine-tuning them and sending them to real quantum hardware.
#
# **Your Task:** After using local testing mode to verify your program, all you need to do is change the backend name to run it on an IBM Quantum system.
#
# </div>

# %%
### Select a Backend
## Use FakeSherbrooke to simulate with noise that matches closer to the real experiment. This will run slower.
## Use AerSimulator to simulate without noise to quickly iterate. This will run faster.

#backend = FakeSherbrooke()
backend = AerSimulator()

# ### Don't change any code past this line ###

# Here we have updated the cost function to return only the energy to be compatible with recent scipy versions (>=1.10)
def cost_func_2(*args, **kwargs):
    energy, result = cost_func(*args, **kwargs)
    return energy

with Session(backend=backend) as session:
    estimator = Estimator(session=session)

    res = minimize(
        cost_func_2,
        x0,
        args=(isa_circuit, hamiltonian_isa, estimator, callback_dict),
        method="Powell",
        options={'maxiter': 30})
# Out:
# -0.4208984375
# -0.37744140625
# 0.0654296875
# -1.4169921875
# -0.220703125
# -1.32958984375
# -1.1533203125
# -1.49609375
# -1.4765625
# -1.47705078125
# -1.4912109375
# -1.4501953125
# -1.48828125
# -1.4755859375
# -0.75048828125
# -1.13916015625
# -1.60107421875
# -1.48583984375
# -1.57861328125
# -1.61181640625
# -1.54833984375
# -1.60107421875
# -1.59912109375
# -1.55517578125
# -1.6025390625
# -1.439453125
# -2.267578125
# -1.72216796875
# -2.34619140625
# -2.15185546875
# -2.33935546875
# -2.3564453125
# -2.36962890625
# -2.3251953125
# -2.31689453125
# -2.38427734375
# -2.33544921875
# -2.40380859375
# -2.4140625
# -2.4091796875
# -2.34912109375
# -2.3935546875
# -2.404296875
# -2.41064453125
# -2.421875
# -2.408203125
# -2.419921875
# -2.41943359375
# -2.4296875
# -2.419921875
# -2.427734375
# -2.42578125
# -2.4130859375
# -2.43798828125
# -2.43115234375
# -2.43115234375
# -2.4169921875
# -2.42919921875
# -2.42333984375
# -2.43603515625
# -2.431640625
# -2.44384765625
# -2.37890625
# -2.01708984375
# -2.77490234375
# -2.10986328125
# -2.5966796875
# -2.72900390625
# -2.76806640625
# -2.69580078125
# -2.751953125
# -2.728515625
# -2.751953125
# -2.7607421875
# -2.751953125
# -2.5888671875
# -1.40966796875
# -2.376953125
# -2.81005859375
# -2.79736328125
# -2.77001953125
# -2.79345703125
# -2.81396484375
# -2.78662109375
# -2.8095703125
# -2.80712890625
# -2.80322265625
# -2.4462890625
# -1.63037109375
# -2.55224609375
# -2.79296875
# -2.8173828125
# -2.80322265625
# -2.80322265625
# -2.8310546875
# -2.81787109375
# -2.81103515625
# -2.80810546875
# -2.810546875
# -2.80322265625
# -2.90771484375
# -1.5595703125
# -2.47607421875
# -2.98046875
# -2.9814453125
# -2.98046875
# -2.96875
# -2.984375
# -2.97998046875
# -2.9833984375
# -2.98046875
# -2.978515625
# -2.97998046875
# -2.9736328125
# -2.98046875
# -2.97900390625
# -2.98388671875
# -2.98486328125
# -2.982421875
# -2.97900390625
# -2.98486328125
# -2.982421875
# -2.984375
# -2.98095703125
# -2.98193359375
# -2.97802734375
# -2.97900390625
# -2.9853515625
# -2.97998046875
# -2.984375
# -2.982421875
# -2.98046875
# -2.9814453125
# -2.984375
# -2.97802734375
# -2.98095703125
# -2.98974609375
# -2.98291015625
# -2.97900390625
# -2.98388671875
# -2.9794921875
# -2.97900390625
# -2.98193359375
# -2.9814453125
# -2.97802734375
# -2.984375
# -2.9814453125
# -2.9814453125
# -2.98388671875
# -2.97998046875
# -2.9775390625
# -2.98046875
# -2.9755859375
# -2.9794921875
# -2.9794921875
# -2.97998046875
# 0.83203125
# -2.982421875
# -2.54443359375
# -1.6220703125
# -2.6865234375
# -2.94287109375
# -2.98388671875
# -2.9873046875
# -2.9873046875
# -2.98828125
# -2.98876953125
# -2.98876953125
# -2.98876953125
# -2.9873046875
# -2.98779296875
# -2.5185546875
# -1.6484375
# -2.7099609375
# -2.931640625
# -2.98681640625
# -2.99169921875
# -2.98974609375
# -2.98388671875
# -2.99169921875
# -2.98876953125
# -2.9892578125
# -2.5966796875
# -1.83056640625
# -2.7509765625
# -2.9287109375
# -2.9912109375
# -2.9921875
# -2.9833984375
# -2.9892578125
# -2.99072265625
# -2.98974609375
# -2.99169921875
# -2.99169921875
# -2.99169921875
# -2.9931640625
# -2.98681640625
# -2.990234375
# -2.99169921875
# -2.9873046875
# -2.9921875
# -2.9921875
# -2.994140625
# -2.9912109375
# -2.98193359375
# -2.9892578125
# -2.9921875
# -2.970703125
# -2.98583984375
# -2.99267578125
# -2.98974609375
# -2.994140625
# -2.9892578125
# -2.9931640625
# -2.9912109375
# -2.99072265625
# -2.9931640625
# -2.99072265625
# -2.98486328125
# -2.9921875
# -2.99267578125
# -2.99072265625
# -2.9482421875
# -2.77392578125
# -2.939453125
# -2.9951171875
# -2.99609375
# -2.99658203125
# -2.99169921875
# -2.9912109375
# -2.99755859375
# -2.9951171875
# -2.99560546875
# -2.99609375
# -2.54638671875
# -1.94482421875
# -2.82177734375
# -2.921875
# -2.99658203125
# -2.99658203125
# -2.9560546875
# -2.99462890625
# -2.98388671875
# -2.990234375
# -2.994140625
# -2.99609375
# -2.9912109375
# -2.9951171875
# -2.99365234375
# -2.9931640625
# -2.99365234375
# -2.99267578125
# -2.9970703125
# -2.51953125
# -1.94677734375
# -2.8115234375
# -2.91943359375
# -2.99609375
# -2.99072265625
# -2.9921875
# -2.99267578125
# -2.9970703125
# -2.9931640625
# -2.99609375
# -2.9921875
# -2.99755859375
# -2.9931640625
# -2.99609375
# -2.99462890625
# -2.9912109375
# -2.99267578125
# -2.99560546875
# -2.9931640625
# -2.99609375
# -2.533203125
# -1.93505859375
# -2.7958984375
# -2.919921875
# -2.9970703125
# -2.978515625
# -2.99267578125
# -2.9951171875
# -2.99169921875
# -2.99658203125
# -2.994140625
# -2.99560546875
# -2.994140625
# -2.99755859375
# -2.99560546875
# -2.9921875
# -2.99169921875
# -2.9912109375
# -2.9951171875
# -2.99658203125
# -2.99609375
# -2.9921875
# -2.9951171875
# -2.99267578125
# -2.99609375
# -2.9951171875
# -2.99560546875
# -2.9951171875
# -2.9951171875
# -2.99462890625
# -2.9921875
# -2.99462890625
# -2.99658203125
# -2.99560546875
# -2.994140625
# -2.99365234375
# -2.9912109375
# -2.9970703125
# -2.99658203125
# -2.9951171875
# -2.99609375
# -2.99169921875
# -2.99560546875
# -2.99169921875
# -2.9951171875
# -2.99609375
# -2.99560546875
# -2.9951171875
# -2.99365234375
# -2.99560546875
# -2.99560546875
# -2.99462890625
# -2.99560546875
# -2.9970703125
# -2.99560546875
# -2.9931640625
# -2.99462890625
# -2.99462890625
# -2.99560546875
# -2.99609375
# -2.99658203125
# -2.99658203125
# -2.97998046875
# -2.9853515625
# -2.451171875
# -1.7314453125
# -2.771484375
# -2.92138671875
# -2.994140625
# -2.99365234375
# -2.99560546875
# -2.99462890625
# -2.994140625
# -2.994140625
# -2.99560546875
# -2.99560546875
# -2.99169921875
# -2.9931640625
# -2.99267578125
# -2.5009765625
# -1.69580078125
# -2.74560546875
# -2.921875
# -2.9921875
# -2.99609375
# -2.9921875
# -2.99365234375
# -2.9931640625
# -2.99365234375
# -2.99072265625
# -2.99267578125
# -2.99169921875
# -2.9912109375
# -2.990234375
# -2.9951171875
# -2.99267578125
# -2.9931640625
# -2.99560546875
# -2.9951171875
# -2.99365234375
# -2.5458984375
# -1.95654296875
# -2.81103515625
# -2.92919921875
# -2.98876953125
# -2.970703125
# -2.98974609375
# -2.9921875
# -2.9931640625
# -2.9951171875
# -2.99169921875
# -2.990234375
# -2.9912109375
# -2.9921875
# -2.994140625
# -2.99462890625
# -2.99609375
# -2.99658203125
# -2.99609375
# -2.9892578125
# -2.9931640625
# -2.99462890625
# -2.994140625
# -2.9951171875
# -2.99755859375
# -2.99658203125
# -2.99755859375
# -2.99609375
# -2.99267578125
# -2.98876953125
# -2.98583984375
# -2.99462890625
# -2.99072265625
# -2.994140625
# -2.99365234375
# -2.99365234375
# -2.99609375
# -2.99365234375
# -2.9873046875
# -2.994140625
# -2.98876953125
# -2.99072265625
# -2.9091796875
# -2.79541015625
# -2.95751953125
# -2.9765625
# -2.98779296875
# -2.990234375
# -2.98974609375
# -2.99609375
# -2.99462890625
# -2.99462890625
# -2.99169921875
# -2.994140625
# -2.99365234375
# -2.98828125
# -2.99462890625
# -2.99072265625
# -2.98974609375
# -2.990234375
# -2.572265625
# -1.86376953125
# -2.7802734375
# -2.9462890625
# -2.9931640625
# -2.9921875
# -2.994140625
# -2.99072265625
# -2.99365234375
# -2.9951171875
# -2.99609375
# -2.99365234375
# -2.99169921875
# -2.990234375
# -2.9951171875
# -2.99462890625
# -2.9951171875
# -2.50146484375
# -1.9599609375
# -2.8203125
# -2.89990234375
# -2.99365234375
# -2.990234375
# -2.99462890625
# -2.99169921875
# -2.994140625
# -2.99560546875
# -2.99560546875
# -2.9912109375
# -2.994140625
# -2.99267578125
# -2.99365234375
# -2.99267578125
# -2.99072265625
# -2.99560546875
# -2.9931640625
# -2.99365234375
# -2.5244140625
# -1.93896484375
# -2.7900390625
# -2.90966796875
# -2.99072265625
# -2.98291015625
# -2.99462890625
# -2.99462890625
# -2.99560546875
# -2.99365234375
# -2.990234375
# -2.994140625
# -2.9873046875
# -2.99169921875
# -2.9951171875
# -2.98828125
# -2.99462890625
# -2.9931640625
# -2.98876953125
# -2.99267578125
# -2.98974609375
# -2.99267578125
# -2.99462890625
# -2.9921875
# -2.99169921875
# -2.9912109375
# -2.994140625
# -2.9931640625
# -2.9912109375
# -2.99267578125
# -2.9921875
# -2.9931640625
# -2.990234375
# -2.99072265625
# -2.99365234375
# -2.9921875
# -2.99072265625
# -2.9912109375
# -2.99658203125
# -2.9892578125
# -2.994140625
# -2.99169921875
# -2.99462890625
# -2.99072265625
# -2.9853515625
# -2.99560546875
# -2.9873046875
# -2.990234375

# %%
# Submit your answer using following code

grade_lab1_ex7(res) # Expected result type: OptimizeResult
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Tip: Increase `maxiter` if you do not see convergence </b>
#
# If the cost is not converging, increase the `maxiter` (100 is an appropriate number) and run Ex 7 again.
#
# </div>

# %% [markdown]
# Let's look at our results:

# %%
fig, ax = plt.subplots()
plt.plot(range(callback_dict["iters"]), callback_dict["cost_history"])
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.draw()

# %% [markdown]
# 🎉 As expected our VQE algorithm minimized our energy across iterations, until reaching the ground state. We have now successfully implemented a VQE algorithm using brand-new Qiskit 1.0 functionalities!

# %% [markdown]
# Thank you for completing this lab, and good luck with the remaining ones!

# %% [markdown]
# # Additional information
#
# **Created by:** James Weaver, Maria Gragera Garces
#
# **Advised by:** Junye Huang
#
# **Version:** 1.3.0
